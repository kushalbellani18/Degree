# %% [markdown]
# # Internal Exam
# #### Kushal Bellani (20162122001)

# %%
import pandas as pd

# %%
#Q1
df = pd.read_excel("Dataset/AB_NYC_2019.csv.xlsx")
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                   Large Furnished Room Near B'way     8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
#Q2
group = df.groupby('room_type')
group.count()['id']
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: id, dtype: int64

# %%
#Q4
df[df['price'] > 150][df['minimum_nights'] < 3][['name', 'host_name']]
# Out:
# /tmp/ipykernel_1522/1698515549.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['price'] > 150][df['minimum_nights'] < 3][['name', 'host_name']]
#                                                     name       host_name
# 1                                  Skylit Midtown Castle        Jennifer
# 16                     Perfect for Your Parents + Garden            Jane
# 51        Cozy 1BD on Central Park West in New York City            Joya
# 62            2 bedroom - Upper East Side-great for kids               D
# 68     *HAVEN LOFT - Entire Floor - Six Windows - Bri...          Daniel
# ...                                                  ...             ...
# 48848   Cute plant friendly studio in hip Brooklyn area!              Em
# 48850          Large studio at Union Square! for 3-5 ppl            Molo
# 48853     Sunny&quiet paradise in the WV with open views        Jennifer
# ...

# %%
#Q5
id = int(input("Enter id: "))
df[df['id'] == id][['name', 'latitude', 'longitude']]
# Out:
# Enter id: 2539
#                                  name  latitude  longitude
# 0  Clean & quiet apt home by the park  40.64749  -73.97237

# %%
#Q6
df.groupby('neighbourhood_group').mean()['price']
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
#Q7
lolPrice = df.groupby('neighbourhood_group').mean()['price']
lolPrice = list(lolPrice)
lolPrice
# Out:
# [87.4967919340055,
#  124.38320732192598,
#  196.8758136743456,
#  99.51764913519237,
#  114.81233243967829]

# %%
lolName = df['neighbourhood_group'].unique()
lolName = list(lolName)
lolName
# Out:
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']

# %%
import matplotlib.pyplot as plt

plt.pie(lolPrice, labels=lolName)
plt.show()

# %%
#Q3
    # Just convert xlsx int csv
df.to_csv('Dataset/ouput2.csv')

# %%
demo = pd.read_csv('Dataset/ouput2.csv')

d = demo.sort_values('name', ascending=0)[['name', 'neighbourhood_group', 'latitude', 'longitude']]

# %%
d.head(10)
# Out:
#                                                    name neighbourhood_group  \
# 47408      ﾏﾝﾊｯﾀﾝ､駅から徒歩4分でどこに行くのにも便利な場所!女性の方希望,ｷﾚｲなお部屋｡           Manhattan
# 27139                           ｳｨﾘｱﾑｽﾞﾊﾞｰｸﾞのかわいいお部屋です2            Brooklyn
# 25823  ️CENTRALLY LOCATED️- Great for Families + Groups           Manhattan
# 36681                                  한성 韓城 Han C (2F)              Queens
# 36481                                  한성 韓城 Han B (2F)              Queens
# 36480                                 한성 韓城 Han A (2FL)              Queens
# 47240                                       안전하고 조용한 숙소           Manhattan
# 21104                                  맨하튼 소호 거리 주변 2인실           Manhattan
# 17054                             뉴욕의 꿈꾸는 집 (for women)           Manhattan
# 47004                                                驿站              Queens
#
#        latitude  longitude
# 47408  40.80347  -73.93522
# 27139  40.71523  -73.96245
# 25823  40.76154  -73.99306
# ...
